# %% [markdown]
# # Py_HackRF test
# https://github.com/hathcox/py-hackrf
# https://github.com/hathcox/py-hackrf/wiki

# %%
import os, sys

def gen_relative_path(target_path): 
    
    def del_same_parents(target_path, current_path):
        if len(target_path) * len(current_path) > 0:
            if target_path[0] == current_path[0]:
                target_path.pop(0)
                current_path.pop(0)
                del_same_parents(target_path, current_path)
            
    current_path = os.getcwd().replace('\\', '/').split('/')
    target_path = target_path.replace('\\', '/').split('/')
    del_same_parents(target_path, current_path)
    
    return ['..'] * len(current_path) + target_path


def append_source_relative_path(source_relative_path):
    sys.path.append(os.sep.join(source_relative_path))

# %%
# paths = [gen_relative_path(p) for p in paths]
# print(paths)

# %%
paths = [['..', 'codes'], 
         ['..', '..', '..', '..', 'ORM', 'bitbucket', 'github', 'codes'], 
         ['..', '..', '..', '..', 'USB', 'Universal Serial Bus', 'bitbucket', 'github', 'codes']]

for path in paths:
    append_source_relative_path(path)

# %%
# %pylab inline  

from py_hackrf import HackRf
from py_hackrf.test import TestHackRf
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
hf = HackRf()
# Out:
# DEBUG:HackRf:Successfully got Board Id

# %%
hf.descriptors_dbos_enum
# Out:
# [(0, 'StandardDeviceDescriptor'),
#  (1, 'StandardConfigurationDescriptor'),
#  (2, 'StandardInterfaceDescriptor'),
#  (3, 'StandardEndpointDescriptor'),
#  (4, 'StandardEndpointDescriptor')]

# %%
hf.endpoints
# Out:
# {129: <ENDPOINT 0x81: Bulk IN>, 2: <ENDPOINT 0x2: Bulk OUT>}

# %%
hf.print_descriptors_dbos()
# Out:
# StandardDeviceDescriptor
# 	bLength: 0x12
# 	bDescriptorType: 0x01
# 	bcdUSB: 0x0002
# 	bDeviceClass: 0x00
# 	bDeviceSubClass: 0x00
# 	bDeviceProtocol: 0x00
# 	bMaxPacketSize0: 0x40
# 	idVendor: 0x501d
# 	idProduct: 0x8960
# 	bcdDevice: 0x0201
# 	iManufacturer: 0x01
# 	iProduct: 0x02
# 	iSerialNumber: 0x04
# 	bNumConfigurations: 0x01
# StandardConfigurationDescriptor
# 	bLength: 0x09
# 	bDescriptorType: 0x02
# 	wTotalLength: 0x2000
# 	bNumInterfaces: 0x01
# 	bConfigurationValue: 0x01
# 	iConfiguration: 0x03
# 	bmAttributes: 0x80
# 	bMaxPower: 0xfa
# StandardInterfaceDescriptor
# 	bLength: 0x09
# 	bDescriptorType: 0x04
# 	bInterfaceNumber: 0x00
# 	bAlternateSetting: 0x00
# 	bNumEndpoints: 0x02
# 	bInterfaceClass: 0xff
# 	bInterfaceSubClass: 0xff
# 	bInterfaceProtocol: 0xff
# 	iInterface: 0x00
# StandardEndpointDescriptor
# 	bLength: 0x07
# 	bDescriptorType: 0x05
# 	bEndpointAddress: 0x81
# 	bmAttributes: 0x02
# 	wMaxPacketSize: 0x0002
# 	bInterval: 0x00
# StandardEndpointDescriptor
# 	bLength: 0x07
# 	bDescriptorType: 0x05
# 	bEndpointAddress: 0x02
# 	bmAttributes: 0x02
# 	wMaxPacketSize: 0x0002
# 	bInterval: 0x00

# %%
hf.max2837.display_registers()
# Out:
# Register 0 Value 848
# Register 1 Value 2
# Register 2 Value 265
# Register 3 Value 441
# Register 4 Value 826
# Register 5 Value 152
# Register 6 Value 6
# Register 7 Value 0
# Register 8 Value 131
# Register 9 Value 24
# Register 10 Value 88
# Register 11 Value 22
# Register 12 Value 591
# Register 13 Value 336
# Register 14 Value 213
# Register 15 Value 129
# Register 16 Value 29
# Register 17 Value 68
# Register 18 Value 273
# Register 19 Value 856
# Register 20 Value 577
# Register 21 Value 45
# Register 22 Value 425
# Register 23 Value 591
# Register 24 Value 384
# Register 25 Value 256
# Register 26 Value 970
# Register 27 Value 995
# Register 28 Value 192
# Register 29 Value 787
# Register 30 Value 128
# Register 31 Value 0

# %%
hf.rffc5071.display_registers()
# Out:
# Register 0 Value 48891
# Register 1 Value 16484
# Register 2 Value 36949
# Register 3 Value 11522
# Register 4 Value 44223
# Register 5 Value 44223
# Register 6 Value 40
# Register 7 Value 40
# Register 8 Value 65280
# Register 9 Value 33312
# Register 10 Value 514
# Register 11 Value 18432
# Register 12 Value 6804
# Register 13 Value 55453
# Register 14 Value 35072
# Register 15 Value 3352
# Register 16 Value 38010
# Register 17 Value 57600
# Register 18 Value 10784
# Register 19 Value 0
# Register 20 Value 0
# Register 21 Value 40960
# Register 22 Value 518
# Register 23 Value 18688
# Register 24 Value 641
# Register 25 Value 61455
# Register 26 Value 0
# Register 27 Value 0
# Register 28 Value 51264
# Register 29 Value 4096
# Register 30 Value 5

# %%
hf.si5351c.display_registers()
# Out:
# Register 0 Value 81
# Register 1 Value 252
# Register 2 Value 3
# Register 3 Value 64
# Register 4 Value 0
# Register 5 Value 0
# Register 6 Value 143
# Register 7 Value 1
# Register 8 Value 0
# Register 9 Value 255
# Register 10 Value 0
# Register 11 Value 0
# Register 12 Value 0
# Register 13 Value 0
# Register 14 Value 144
# Register 15 Value 8
# Register 16 Value 12
# Register 17 Value 72
# Register 18 Value 72
# Register 19 Value 79
# Register 20 Value 78
# Register 21 Value 77
# Register 22 Value 192
# Register 23 Value 79
# Register 24 Value 0
# Register 25 Value 0
# Register 26 Value 0
# Register 27 Value 1
# Register 28 Value 0
# Register 29 Value 14
# Register 30 Value 0
# Register 31 Value 0
# Register 32 Value 0
# Register 33 Value 0
# Register 34 Value 0
# Register 35 Value 1
# Register 36 Value 0
# Register 37 Value 38
# Register 38 Value 0
# Register 39 Value 0
# Register 40 Value 0
# Register 41 Value 0
# Register 42 Value 18
# Register 43 Value 211
# Register 44 Value 16
# Register 45 Value 91
# Register 46 Value 72
# Register 47 Value 0
# Register 48 Value 13
# Register 49 Value 168
# Register 50 Value 0
# Register 51 Value 0
# Register 52 Value 0
# Register 53 Value 0
# Register 54 Value 0
# Register 55 Value 0
# Register 56 Value 0
# Register 57 Value 0
# Register 58 Value 0
# Register 59 Value 0
# Register 60 Value 0
# Register 61 Value 0
# Register 62 Value 0
# Register 63 Value 0
# Register 64 Value 0
# Register 65 Value 0
# Register 66 Value 0
# Register 67 Value 1
# Register 68 Value 0
# Register 69 Value 38
# Register 70 Value 0
# Register 71 Value 0
# Register 72 Value 0
# Register 73 Value 0
# Register 74 Value 0
# Register 75 Value 1
# Register 76 Value 0
# Register 77 Value 6
# Register 78 Value 0
# Register 79 Value 0
# Register 80 Value 0
# Register 81 Value 0
# Register 82 Value 0
# Register 83 Value 1
# Register 84 Value 0
# Register 85 Value 8
# Register 86 Value 0
# Register 87 Value 0
# Register 88 Value 0
# Register 89 Value 0
# Register 90 Value 255
# Register 91 Value 20
# Register 92 Value 0
# Register 93 Value 0
# Register 94 Value 0
# Register 95 Value 0
# Register 96 Value 0
# Register 97 Value 0
# Register 98 Value 0
# Register 99 Value 0
# Register 100 Value 0
# Register 101 Value 0
# Register 102 Value 0
# Register 103 Value 0
# Register 104 Value 0
# Register 105 Value 0
# Register 106 Value 0
# Register 107 Value 0
# Register 108 Value 0
# Register 109 Value 0
# Register 110 Value 0
# Register 111 Value 0
# Register 112 Value 0
# Register 113 Value 0
# Register 114 Value 0
# Register 115 Value 0
# Register 116 Value 0
# Register 117 Value 0
# Register 118 Value 0
# Register 119 Value 0
# Register 120 Value 0
# Register 121 Value 0
# Register 122 Value 0
# Register 123 Value 0
# Register 124 Value 0
# Register 125 Value 0
# Register 126 Value 0
# Register 127 Value 0
# Register 128 Value 0
# Register 129 Value 0
# Register 130 Value 0
# Register 131 Value 0
# Register 132 Value 0
# Register 133 Value 0
# Register 134 Value 0
# Register 135 Value 0
# Register 136 Value 0
# Register 137 Value 0
# Register 138 Value 0
# Register 139 Value 0
# Register 140 Value 0
# Register 141 Value 0
# Register 142 Value 0
# Register 143 Value 0
# Register 144 Value 0
# Register 145 Value 0
# Register 146 Value 0
# Register 147 Value 0
# Register 148 Value 0
# Register 149 Value 0
# Register 150 Value 0
# Register 151 Value 0
# Register 152 Value 0
# Register 153 Value 0
# Register 154 Value 0
# Register 155 Value 0
# Register 156 Value 0
# Register 157 Value 0
# Register 158 Value 0
# Register 159 Value 0
# Register 160 Value 0
# Register 161 Value 0
# Register 162 Value 0
# Register 163 Value 0
# Register 164 Value 0
# Register 165 Value 0
# Register 166 Value 0
# Register 167 Value 0
# Register 168 Value 0
# Register 169 Value 0
# Register 170 Value 0
# Register 171 Value 0
# Register 172 Value 0
# Register 173 Value 0
# Register 174 Value 0
# Register 175 Value 0
# Register 176 Value 255
# Register 177 Value 12
# Register 178 Value 0
# Register 179 Value 0
# Register 180 Value 0
# Register 181 Value 48
# Register 182 Value 31
# Register 183 Value 128
# Register 184 Value 96
# Register 185 Value 96
# Register 186 Value 184
# Register 187 Value 210
# Register 188 Value 0
# Register 189 Value 0
# Register 190 Value 0
# Register 191 Value 0
# Register 192 Value 0
# Register 193 Value 0
# Register 194 Value 0
# Register 195 Value 0
# Register 196 Value 0
# Register 197 Value 0
# Register 198 Value 0
# Register 199 Value 0
# Register 200 Value 0
# Register 201 Value 0
# Register 202 Value 0
# Register 203 Value 0
# Register 204 Value 0
# Register 205 Value 67
# Register 206 Value 220
# Register 207 Value 0
# Register 208 Value 0
# Register 209 Value 0
# Register 210 Value 0
# Register 211 Value 128
# Register 212 Value 0
# Register 213 Value 0
# Register 214 Value 0
# Register 215 Value 0
# Register 216 Value 0
# Register 217 Value 0
# Register 218 Value 28
# Register 219 Value 0
# Register 220 Value 0
# Register 221 Value 0
# Register 222 Value 255
# Register 223 Value 255
# Register 224 Value 63
# Register 225 Value 0
# Register 226 Value 60
# Register 227 Value 112
# Register 228 Value 0
# Register 229 Value 0
# Register 230 Value 0
# Register 231 Value 0
# Register 232 Value 0
# Register 233 Value 0
# Register 234 Value 0
# Register 235 Value 0
# Register 236 Value 0
# Register 237 Value 0
# Register 238 Value 0
# Register 239 Value 0
# Register 240 Value 0
# Register 241 Value 0
# Register 242 Value 0
# Register 243 Value 0
# Register 244 Value 0
# Register 245 Value 0
# Register 246 Value 0
# Register 247 Value 0
# Register 248 Value 0
# Register 249 Value 0
# Register 250 Value 0
# Register 251 Value 0
# Register 252 Value 0
# Register 253 Value 0
# Register 254 Value 0

# %%
del hf

# %%
import unittest

from py_hackrf.test import TestHackRf


suite = unittest.TestLoader().loadTestsFromTestCase(TestHackRf)
unittest.TextTestRunner(verbosity = 2).run(suite)
# Out:
# test_disable_amp (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully disabled Amp
# ok
# test_enable_amp (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully enabled Amp
# ok
# test_get_board_id (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully got Board Id
# ok
# test_get_board_serial_number (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully got the HackRf Board Serial Number
# ok
# test_get_version_string (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully got HackRf Version String
# ok
# test_set_baseband_filter_bandwidth (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully set Baseband Filter Bandwidth with value [500000]
# ERROR:HackRf:Failed to set Baseband Filter Bandwidth, bandwidth_hz should be of type INT or LONG
# ok
# test_set_frequency (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Frequency [10] Mhz | [0] Hz
# DEBUG:HackRf:Successfully set frequency with value [10000000]
# ERROR:HackRf:Error setting frequency, value should be of type INT or LONG
# ok
# test_set_lna_gain (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully set LNA gain to [14]
# ERROR:HackRf:Failed to set LNA gain, gain should be of type INT or LONG
# ERROR:HackRf:Failed to set LNA gain, value must be less than 41
# ok
# test_set_rx_mode (py_hackrf.test.TestHackRf) ... DEBUG:HackRf:Successfully got Board Id
# DEBUG:HackRf:Successfully set HackRf in Recieve Mode
# ok
# test_set_sample_rate (py_hackrf.test.TestHackRf) ...
# ('00000000', '00000000', '901868DC', '284B908B')
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 915, in reset
#     self._ctx.backend.reset_device(self._ctx.handle)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 602, in reset_device
#     _check(_lib.usb_reset(dev_handle))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [reset] could not reset device, win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 915, in reset
#     self._ctx.backend.reset_device(self._ctx.handle)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 602, in reset_device
#     _check(_lib.usb_reset(dev_handle))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [reset] could not reset device, win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# Exception ignored in: <bound method USBdevice.__del__ of <DEVICE ID 1d50:6089 on Bus 000 Address 012>>
# Traceback (most recent call last):
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 79, in __del__
#     self.close()
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 107, in close
#     self.reset()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 913, in reset
#     self._ctx.managed_open()
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 102, in wrapper
#     return f(self, *args, **kwargs)
#   File "C:\Softwares\Python\lib\site-packages\usb\core.py", line 120, in managed_open
#     self.handle = self.backend.open_device(self.dev)
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 485, in open_device
#     return _check(_lib.usb_open(dev))
#   File "C:\Softwares\Python\lib\site-packages\usb\backend\libusb0.py", line 431, in _check
#     raise USBError(errmsg, ret)
# usb.core.USBError: [Errno None] b'libusb0-dll:err [os_open] failed to open \\\\.\\libusb0-0012--0x1d50-0x6089: win error: \xab\xfc\xa9w\xaa\xba\xb8\xcb\xb8m\xa4\xa3\xa6s\xa6b\xa1C\r\n'
# ERROR
# test_set_tx_mode (py_hackrf.test.TestHackRf) ... ERROR
# test_set_txvga_gain (py_hackrf.test.TestHackRf) ... ERROR
# test_set_vga_gain (py_hackrf.test.TestHackRf) ... ERROR
#
# ======================================================================
# ERROR: test_set_sample_rate (py_hackrf.test.TestHackRf)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "..\codes\py_hackrf\test\__init__.py", line 10, in setUp
#     self.hackrf = HackRf()
#   File "..\codes\py_hackrf\__init__.py", line 85, in __init__
#     super().__init__(vid, pid, address)
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 54, in __init__
#     raise ValueError("Device not found ({:x}:{:x} address:{})".format(vid, pid, address or ''))
# ValueError: Device not found (1d50:6089 address:)
#
# ======================================================================
# ERROR: test_set_tx_mode (py_hackrf.test.TestHackRf)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "..\codes\py_hackrf\test\__init__.py", line 10, in setUp
#     self.hackrf = HackRf()
#   File "..\codes\py_hackrf\__init__.py", line 85, in __init__
#     super().__init__(vid, pid, address)
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 54, in __init__
#     raise ValueError("Device not found ({:x}:{:x} address:{})".format(vid, pid, address or ''))
# ValueError: Device not found (1d50:6089 address:)
#
# ======================================================================
# ERROR: test_set_txvga_gain (py_hackrf.test.TestHackRf)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "..\codes\py_hackrf\test\__init__.py", line 10, in setUp
#     self.hackrf = HackRf()
#   File "..\codes\py_hackrf\__init__.py", line 85, in __init__
#     super().__init__(vid, pid, address)
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 54, in __init__
#     raise ValueError("Device not found ({:x}:{:x} address:{})".format(vid, pid, address or ''))
# ValueError: Device not found (1d50:6089 address:)
#
# ======================================================================
# ERROR: test_set_vga_gain (py_hackrf.test.TestHackRf)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "..\codes\py_hackrf\test\__init__.py", line 10, in setUp
#     self.hackrf = HackRf()
#   File "..\codes\py_hackrf\__init__.py", line 85, in __init__
#     super().__init__(vid, pid, address)
#   File "..\..\..\..\USB\Universal Serial Bus\bitbucket\github\codes\universal_serial_bus\__init__.py", line 54, in __init__
#     raise ValueError("Device not found ({:x}:{:x} address:{})".format(vid, pid, address or ''))
# ValueError: Device not found (1d50:6089 address:)
#
# ----------------------------------------------------------------------
# Ran 13 tests in 0.448s
#
# FAILED (errors=4)
# <unittest.runner.TextTestResult run=13 errors=4 failures=0>
